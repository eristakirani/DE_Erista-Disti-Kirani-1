# %% [markdown]
# ### Import Library & Extract Data

# %%
import pandas as pd

df = pd.read_csv("tx_data.csv")
df
# Out:
#      transaction_id     customer_name  transaction_amount  phone_number  \
# 0                 1         John Thor               54000   81234564030
# 1                 2        Jane Smith               25000   81234567891
# 2                 3   Michael Johnson               75000   81234567892
# 3                 4       Emily Davis               32000   81234567893
# 4                 5      David Wilson               45000   81234567894
# ..              ...               ...                 ...           ...
# 115             116         Mary Hall               48000   81234567825
# 116             117     James Jackson               37000   81234567826
# 117             118  Elizabeth Turner               54000   81234567827
# 118             119      Robert Smith               25000   81234567828
# 119             120   Margaret Wilson               75000   81234567829
#
#     transaction_type transaction_status
# 0         paket data            success
# ...

# %%
# Mengubah nomor telepon menjadi string dan menambahkan '+62' di depannya
df['phone_number'] = df['phone_number'].apply(lambda x: '+62' + str(x))

# Menampilkan DataFrame yang telah dimodifikasi
df
# Out:
#      transaction_id     customer_name  transaction_amount    phone_number  \
# 0                 1         John Thor               54000  +6281234564030
# 1                 2        Jane Smith               25000  +6281234567891
# 2                 3   Michael Johnson               75000  +6281234567892
# 3                 4       Emily Davis               32000  +6281234567893
# 4                 5      David Wilson               45000  +6281234567894
# ..              ...               ...                 ...             ...
# 115             116         Mary Hall               48000  +6281234567825
# 116             117     James Jackson               37000  +6281234567826
# 117             118  Elizabeth Turner               54000  +6281234567827
# 118             119      Robert Smith               25000  +6281234567828
# 119             120   Margaret Wilson               75000  +6281234567829
#
#     transaction_type transaction_status
# ...

# %%
# Mengonversi nilai 'transaction_amount' dan menambahkan awalan mata uang 'Rp '
df['transaction_amount'] = df['transaction_amount'].apply(lambda x: "Rp {:,.0f}".format(x).replace(",", "."))

# Menampilkan DataFrame yang telah dimodifikasi
df
# Out:
#      transaction_id     customer_name transaction_amount    phone_number  \
# 0                 1         John Thor          Rp 54.000  +6281234564030
# 1                 2        Jane Smith          Rp 25.000  +6281234567891
# 2                 3   Michael Johnson          Rp 75.000  +6281234567892
# 3                 4       Emily Davis          Rp 32.000  +6281234567893
# 4                 5      David Wilson          Rp 45.000  +6281234567894
# ..              ...               ...                ...             ...
# 115             116         Mary Hall          Rp 48.000  +6281234567825
# 116             117     James Jackson          Rp 37.000  +6281234567826
# 117             118  Elizabeth Turner          Rp 54.000  +6281234567827
# 118             119      Robert Smith          Rp 25.000  +6281234567828
# 119             120   Margaret Wilson          Rp 75.000  +6281234567829
#
#     transaction_type transaction_status
# 0         paket data            success
# ...

# %%
df = df[df['transaction_status'] == 'success']
df
# Out:
#      transaction_id     customer_name transaction_amount    phone_number  \
# 0                 1         John Thor          Rp 54.000  +6281234564030
# 1                 2        Jane Smith          Rp 25.000  +6281234567891
# 3                 4       Emily Davis          Rp 32.000  +6281234567893
# 5                 6    Susan Anderson          Rp 61.000  +6281234567895
# 6                 7      Robert Clark          Rp 29.000  +6281234567896
# ..              ...               ...                ...             ...
# 113             114   Sharon Anderson          Rp 61.000  +6281234567823
# 114             115       David Davis          Rp 29.000  +6281234567824
# 115             116         Mary Hall          Rp 48.000  +6281234567825
# 117             118  Elizabeth Turner          Rp 54.000  +6281234567827
# 118             119      Robert Smith          Rp 25.000  +6281234567828
#
#     transaction_type transaction_status
# 0         paket data            success
# ...
